# %% [markdown]
# # Importar bibliotecas

# %%
import pandas as pd
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 200

# %% [markdown]
# # Ler o estoque

# %%
patt = './*/*Estoque*.csv'
list_files = glob(patt)

# %%
file = list_files[0]

# %%
# Colunas que contêm datas.
colunas_data = [
    'DataEmissao',
    'DataAquisicao',
    'DataVencimento',
    'DataGeracao'
]

colunas_texto = [
    'Situacao', 'PES_TIPO_PESSOA', 'CedenteCnpjCpf', 'TIT_CEDENTE_ENT_CODIGO',
    'CedenteNome', 'Cnae', 'SecaoCNAEDescricao', 'NotaPdd', 'SAC_TIPO_PESSOA',
    'SacadoCnpjCpf', 'SacadoNome', 'IdTituloVortx', 'TipoAtivo', 'NumeroBoleto',
    'NumeroTitulo', 'CampoChave', 'PagamentoParcial', 'Coobricacao',
    'CampoAdicional1', 'CampoAdicional2', 'CampoAdicional3', 'CampoAdicional4',
    'CampoAdicional5', 'IdTituloVortxOriginador', 'Registradora',
    'IdContratoRegistradora', 'IdTituloRegistradora', 'CCB', 'Convênio'
]

#*Numéricas: 
colunas_numericas = [
    'ValorAquisicao', 'ValorNominal', 'ValorPresente', 'PDDNota', 'PDDVencido',
    'PDDTotal', 'PDDEfeitoVagao', 'PercentagemEfeitoVagao'
]

# dic pra ler as de texto
dtype_texto = {col: str for col in colunas_texto}

# %%
# %%time
dfs = []
for file in list_files:
    df_ = pd.read_csv(file, sep=';', encoding='latin1', dtype=dtype_texto, 
                      decimal=',', parse_dates=colunas_data, dayfirst=True)
    dfs.append(df_)
# Out:
# CPU times: user 7.84 s, sys: 691 ms, total: 8.54 s
# Wall time: 8.72 s

# %%
# %%time
df_final = pd.concat(dfs)
# Out:
# CPU times: user 5.99 s, sys: 50 ms, total: 6.04 s
# Wall time: 6.04 s

# %%
# criar colunas auxiliares
df_final['_ValorLiquido'] = df_final['ValorPresente'] - df_final['PDDTotal']
df_final['_ValorVencido'] = (df_final['DataVencimento'] <= df_final['DataGeracao']).astype('int') * df_final['ValorPresente']

# sacados com muitos contratos
sacado_contratos = df_final.groupby('SacadoNome')['CCB'].nunique()
k = 3 # numero alto
mask = sacado_contratos[sacado_contratos >= k]
sacado_contratos_alto = sacado_contratos.index[mask]
df_final['_MuitosContratos'] = df_final['SacadoNome'].isin(sacado_contratos_alto).astype('str')

# sacados com muitos entes
sacados_entes = df_final.groupby('SacadoCnpjCpf')['Convênio'].nunique()
k2 = 3
mask = sacados_entes >= k2
sacados_entes_alto = sacados_entes.index[mask]
df_final['_MuitosEntes'] = df_final['SacadoCnpjCpf'].isin(sacados_entes_alto).astype('str')

# %%
df_final.memory_usage(deep=True).sum()/1024**2
# Out:
# 3049.7270975112915

# %%
# Tamanho do estoque
print(f'{df_final["ValorPresente"].sum():_.2f}')
# Out:
# 199_232_147.56

# %% [markdown]
# # Analisar com `value_counts()`
# ### Comentários / dúvidas
# 1. [Situacao] - diferença entre sem cobrança e aditado
# 2. [SAC_TIPO_PESSOA] - tipo J = jurídico?? tem isso?
# 3. [SacadoCnpjCpf] - por que tem CNPJ?
# 4. [SacadoNome] 'BMP SOCIEDADE DE CREDITO DIRETO S.A'
# 5. [SacadoCnpjCpf'] - verificar consistência dos CPFs
# 6. [TipoAtivo] - CCB e Contrato. Por que tem contrato?
# 7. [DataGeracao] - data de referência ou data de processamento?
# 8. [SacadoCnpjCpf] - tem sacado com 1040 linhas (!)
# 9. [Convênio] - sacados com muitos convênios (3)

# %%
df_final2 = df_final[~df_final['Situacao'].isna()].copy()

for col in df_final2.columns:
    if not df_final2[col].dtype == df_final2['Situacao'].dtype:
        continue
    print(df_final2[col].value_counts(dropna=False))
    print('*'*80)
# Out:
# Situacao
# Sem cobranÃ§a    1471376
# Aditado            50939
# Name: count, dtype: int64
# ********************************************************************************
# PES_TIPO_PESSOA
# J    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CedenteCnpjCpf
# 34.337.707/0001-00    1519907
# 92.874.270/0001-40       2408
# Name: count, dtype: int64
# ********************************************************************************
# TIT_CEDENTE_ENT_CODIGO
# 318853     1519907
# 3224693       2408
# Name: count, dtype: int64
# ********************************************************************************
# CedenteNome
# BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A    1519907
# BANCO DIGIMAIS S.A.                                  2408
# Name: count, dtype: int64
# ********************************************************************************
# Cnae
# 6499999    1519907
# 6422100       2408
# Name: count, dtype: int64
# ********************************************************************************
# SecaoCNAEDescricao
# OUTRAS ATIVIDADES DE SERVIÃOS FINANCEIROS NÃO ESPECIFICADAS ANTERIORMENTE    1519907
# BANCOS MÃLTIPLOS, COM CARTEIRA COMERCIAL                                         2408
# Name: count, dtype: int64
# ********************************************************************************
# NotaPdd
# AA    1522315
# Name: count, dtype: int64
# ********************************************************************************
# SAC_TIPO_PESSOA
# F    1165729
# J     356586
# Name: count, dtype: int64
# ********************************************************************************
# SacadoCnpjCpf
# 619.387.855-68    1040
# 429.353.263-34     979
# 025.463.755-80     930
# 003.076.413-09     823
# 912.732.935-68     823
#                   ...
# 071.472.927-23       1
# 079.634.488-42       1
# 285.008.288-03       1
# 602.141.399-72       1
# 871.553.037-04       1
# Name: count, Length: 18789, dtype: int64
# ********************************************************************************
# SacadoNome
# LUCIA VALERIA OLIVEIRA BASTOS DA SILVA    1040
# ROMILDO SOUSA SERAFIM                      979
# JAQUELINE BORGES DE OLIVEIRA BELEM         930
# Natalino Dos Santos Silva                  823
# JEANE DE MIRANDA RODRIGUES                 823
#                                           ...
# MARIA DO PERPETUO SOCORRO LIMA LEAL          1
# JEFFERSON MENEZES SANTOS                     1
# ARYNEIA BUNA FERREIRA LIMA                   1
# CLAUDIA REGINA LISBOA DE OLIVEIRA            1
# JANE REGINA MOLINA DE OLIVEIRA               1
# Name: count, Length: 18736, dtype: int64
# ********************************************************************************
# IdTituloVortx
# 81669857    1
# 83725356    1
# 83725365    1
# 83725364    1
# 83725363    1
#            ..
# 66909003    1
# 66907121    1
# 66886816    1
# 66906405    1
# 86464421    1
# Name: count, Length: 1522315, dtype: int64
# ********************************************************************************
# TipoAtivo
# CCB              1438878
# CT - Contrato      83437
# Name: count, dtype: int64
# ********************************************************************************
# NumeroBoleto
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# NumeroTitulo
# 49170127003    1
# 49999755037    1
# 49999755046    1
# 49999755045    1
# 49999755044    1
#               ..
# 44569917016    1
# 44569917068    1
# 44569917084    1
# 44569917049    1
# 51228907060    1
# Name: count, Length: 1522315, dtype: int64
# ********************************************************************************
# CampoChave
# 49170127003    1
# 49999755037    1
# 49999755046    1
# 49999755045    1
# 49999755044    1
#               ..
# 182081924      1
# 182081752      1
# 182081653      1
# 182081150      1
# 51228907060    1
# Name: count, Length: 1522315, dtype: int64
# ********************************************************************************
# PagamentoParcial
# NAO    1518516
# SIM       3799
# Name: count, dtype: int64
# ********************************************************************************
# Coobricacao
# NAO    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional1
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional2
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional3
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional4
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional5
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# IdTituloVortxOriginador
# 0           1076486
# 67161481        625
# 80594854        466
# 63737361        462
# 37851842        461
#              ...
# 45563737          1
# 46168778          1
# 46167644          1
# 46250149          1
# 46860272          1
# Name: count, Length: 5011, dtype: int64
# ********************************************************************************
# Registradora
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# IdContratoRegistradora
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# IdTituloRegistradora
# NaN    1522315
# Name: count, dtype: int64
# ********************************************************************************
# CCB
# 53561654    96
# 51642117    96
# 57280760    96
# 54508712    96
# 54160912    96
#             ..
# 40355772     1
# 40235251     1
# 39913791     1
# 39720381     1
# 39831423     1
# Name: count, Length: 26391, dtype: int64
# ********************************************************************************
# Convênio
# GOV. MARANHAO                                314033
# GOV. ALAGOAS                                 219090
# GOV. RIO GRANDE DO NORTE                      86286
# PREF. CAMPOS DOS GOYTACAZES                   73339
# GOV. GOIAS                                    73289
# PREF. BARREIRAS                               71024
# GOV. TOCANTINS                                70151
# PREF. BALSAS                                  60782
# PREF. CABO FRIO                               49898
# PREF. CASTANHAL                               37086
# PREF. ABAETETUBA                              24630
# PREF. ICATU                                   22383
# GOV. AMAZONAS                                 22217
# PREF. FLORIANÓPOLIS                           21256
# PREF. SANTO ANDRE                             17855
# PREF. PERITORO                                17767
# PREF. CACHOEIRA GRANDE                        15759
# PREF. TUTOIA                                  15715
# PREF. ÓBIDOS                                  14874
# PREF. RIO DE JANEIRO                          13703
# PREF. BOA VISTA                               12188
# PREF. PORTO NACIONAL                          12175
# PREF. PASTOS BONS                             11076
# PREF. SÃO LUIS                                10968
# PREF. MAUÁ                                    10466
# PREF. CAJAMAR                                 10398
# PREF. TUMTUM                                  10081
# PREF. MONÇÃO                                   9696
# PREF. ITAPIPOCA                                9226
# PREF. CASA NOVA                                9201
# PREF. MARINGA                                  7854
# Prefeitura Municipal de Ananindeua              144
# PREFEITURA MUNICIPAL DE MARINGA                 144
# PREF. DOUTOR CAMARGO                            132
# PREF. OURIZONA                                  131
# PREV. QUIXERAMOBIM                              131
# PREF. SÃO BERNARDO                              120
# PREF. GURUPI                                    108
# GOV. MATO GROSSO                                 96
# Prefeitura Municipal de Juazeiro do Norte        96
# PREF. JUNDIAÍ                                    96
# PREF. RECIFE                                     90
# PREV. GOIANESIA                                  84
# PREF. IMBAÚ                                      84
# PREF. CALDAS NOVAS                               60
# PREF. APUCARANA                                  59
# IAM MARINGA                                      59
# PREF. PORTEIRÃO                                  48
# PREF. BAURU                                      46
# ASSEMBLEIA. MATO GROSSO                          44
# PREF. LEOPOLDO DE BULHOES                        36
# PREF. TABULEIRO DO NORTE                         36
# PREF. CAMPINA GRANDE                             35
# PREFEITURA MUNICIPAL DE PIRACICABA               35
# PREFEITURA MUNICIPAL DE ANANINDEUA               24
# PREV. PORTO CALVO                                17
# Name: count, dtype: int64
# ********************************************************************************
# _MuitosContratos
# False    1520460
# True        1855
# Name: count, dtype: int64
# ********************************************************************************
# _MuitosEntes
# False    1516869
# True        5446
# Name: count, dtype: int64
# ********************************************************************************

# %% [markdown]
# # Verificando as 117.984 linhas com dados nulos
# Pela análise abaixo, não tem influência no cálculo

# %%
df_final[df_final['Situacao'].isna()].apply(lambda x: (min(x), max(x)))
# Out:
#    Situacao  PES_TIPO_PESSOA  CedenteCnpjCpf  TIT_CEDENTE_ENT_CODIGO  \
# 0       NaN              NaN             NaN                     NaN
# 1       NaN              NaN             NaN                     NaN
#
#    CedenteNome  Cnae  SecaoCNAEDescricao  NotaPdd  SAC_TIPO_PESSOA  \
# 0          NaN   NaN                 NaN      NaN              NaN
# 1          NaN   NaN                 NaN      NaN              NaN
#
#    SacadoCnpjCpf  SacadoNome  IdTituloVortx  TipoAtivo DataEmissao  \
# 0            NaN         NaN            NaN        NaN         NaT
# 1            NaN         NaN            NaN        NaN         NaT
#
#   DataAquisicao DataVencimento  NumeroBoleto  NumeroTitulo  CampoChave  \
# 0           NaT            NaT           NaN           NaN         NaN
# 1           NaT            NaT           NaN           NaN         NaN
#
#    ValorAquisicao  ValorNominal  ValorPresente  PDDNota  PDDVencido  \
# 0             NaN           NaN            NaN      NaN         NaN
# 1             NaN           NaN            NaN      NaN         NaN
#
#    PagamentoParcial  Coobricacao DataGeracao  PDDTotal  CampoAdicional1  \
# 0               NaN          NaN         NaT       NaN              NaN
# 1               NaN          NaN         NaT       NaN              NaN
#
#    CampoAdicional2  CampoAdicional3  CampoAdicional4  CampoAdicional5  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
#
#    PDDEfeitoVagao  PercentagemEfeitoVagao  IdTituloVortxOriginador  \
# 0             NaN                     NaN                      NaN
# 1             NaN                     NaN                      NaN
#
#    Registradora  IdContratoRegistradora  IdTituloRegistradora  CCB  Convênio
# 0           NaN                     NaN                   NaN  NaN       NaN
# 1           NaN                     NaN                   NaN  NaN       NaN

# %%
v1_ = df_final['ValorPresente'].sum() 
v2_ = df_final[~df_final['Situacao'].isna()]['ValorPresente'].sum()
np.isclose(v1_, v2_)
# Out:
# True

# %%
del df_final

# %% [markdown]
# # Sacado == 'J'
# aqui não tem problema

# %%
df_sacado_J = df_final2[df_final2['SAC_TIPO_PESSOA'] == 'J'].sample(5)

# %%
df_sacado_J['SacadoCnpjCpf'].map(len).max()
# Out:
# 14

# %% [markdown]
# # Sacado com CNPJ

# %%
set(df_final2['SacadoCnpjCpf'].apply(len))
# Out:
# {14, 18}

# %%
df_final2_cnpj = df_final2[df_final2['SacadoCnpjCpf'].map(len)==18]
df_final2_cnpj['SacadoNome'].unique()
# Out:
# array(['BMP SOCIEDADE DE CREDITO DIRETO S.A'], dtype=object)

# %%
for col in df_final2_cnpj.columns:
    if not df_final2_cnpj[col].dtype == df_final2_cnpj['Situacao'].dtype:
        continue
    print(df_final2_cnpj[col].value_counts(dropna=False))
    print('*'*80)
# Out:
# Situacao
# Sem cobranÃ§a    95
# Name: count, dtype: int64
# ********************************************************************************
# PES_TIPO_PESSOA
# J    95
# Name: count, dtype: int64
# ********************************************************************************
# CedenteCnpjCpf
# 34.337.707/0001-00    95
# Name: count, dtype: int64
# ********************************************************************************
# TIT_CEDENTE_ENT_CODIGO
# 318853    95
# Name: count, dtype: int64
# ********************************************************************************
# CedenteNome
# BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A    95
# Name: count, dtype: int64
# ********************************************************************************
# Cnae
# 6499999    95
# Name: count, dtype: int64
# ********************************************************************************
# SecaoCNAEDescricao
# OUTRAS ATIVIDADES DE SERVIÃOS FINANCEIROS NÃO ESPECIFICADAS ANTERIORMENTE    95
# Name: count, dtype: int64
# ********************************************************************************
# NotaPdd
# AA    95
# Name: count, dtype: int64
# ********************************************************************************
# SAC_TIPO_PESSOA
# J    95
# Name: count, dtype: int64
# ********************************************************************************
# SacadoCnpjCpf
# 34.337.707/0001-00    95
# Name: count, dtype: int64
# ********************************************************************************
# SacadoNome
# BMP SOCIEDADE DE CREDITO DIRETO S.A    95
# Name: count, dtype: int64
# ********************************************************************************
# IdTituloVortx
# 59408244    1
# 59408166    1
# 59408205    1
# 59408241    1
# 59408213    1
#            ..
# 59408235    1
# 59408248    1
# 59408203    1
# 59408192    1
# 59408178    1
# Name: count, Length: 95, dtype: int64
# ********************************************************************************
# TipoAtivo
# CCB    95
# Name: count, dtype: int64
# ********************************************************************************
# NumeroBoleto
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# NumeroTitulo
# 42360495060    1
# 42360495041    1
# 42360495048    1
# 42360495050    1
# 42360495017    1
#               ..
# 42360495067    1
# 42360495027    1
# 42360495028    1
# 42360495045    1
# 42360495042    1
# Name: count, Length: 95, dtype: int64
# ********************************************************************************
# CampoChave
# 181573529    1
# 181573589    1
# 181573598    1
# 181573597    1
# 181573596    1
#             ..
# 181573558    1
# 181573557    1
# 181573556    1
# 181573555    1
# 181573624    1
# Name: count, Length: 95, dtype: int64
# ********************************************************************************
# PagamentoParcial
# NAO    95
# Name: count, dtype: int64
# ********************************************************************************
# Coobricacao
# NAO    95
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional1
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional2
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional3
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional4
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# CampoAdicional5
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# IdTituloVortxOriginador
# 59408221    95
# Name: count, dtype: int64
# ********************************************************************************
# Registradora
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# IdContratoRegistradora
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# IdTituloRegistradora
# NaN    95
# Name: count, dtype: int64
# ********************************************************************************
# CCB
# 42360495    95
# Name: count, dtype: int64
# ********************************************************************************
# Convênio
# PREF. POÁ    95
# Name: count, dtype: int64
# ********************************************************************************

# %%
df_final2_cnpj.describe(include=[np.number])
# Out:
#        ValorAquisicao  ValorNominal  ValorPresente  PDDNota  PDDVencido  \
# count       95.000000  9.500000e+01      95.000000     95.0   95.000000
# mean        23.177368  5.613000e+01      27.604434      0.0    1.650542
# std         13.054230  1.428624e-14      15.121244      0.0    8.263526
# min          7.310000  5.613000e+01       8.795000      0.0    0.000000
# 25%         12.005000  5.613000e+01      14.445900      0.0    0.000000
# 50%         19.710000  5.613000e+01      23.720600      0.0    0.000000
# 75%         32.350000  5.613000e+01      38.939150      0.0    0.000000
# max         53.070000  5.613000e+01      56.130000      0.0   56.130000
#
#         PDDTotal  PDDEfeitoVagao  PercentagemEfeitoVagao
# count  95.000000       95.000000                    95.0
# mean   27.604434       27.604434                     1.0
# std    15.121244       15.121244                     0.0
# min     8.795000        8.795000                     1.0
# 25%    14.445900       14.445900                     1.0
# 50%    23.720600       23.720600                     1.0
# 75%    38.939150       38.939150                     1.0
# max    56.130000       56.130000                     1.0

# %%
df_final2_cnpj.select_dtypes(include=[np.number]).sum()
# Out:
# ValorAquisicao            2201.8500
# ValorNominal              5332.3500
# ValorPresente             2622.4212
# PDDNota                      0.0000
# PDDVencido                 156.8015
# PDDTotal                  2622.4212
# PDDEfeitoVagao            2622.4212
# PercentagemEfeitoVagao      95.0000
# dtype: float64

# %%
# Exportar para excel
df_final2_cnpj.to_excel('df_final2_cnpj.xlsx')

# %% [markdown]
# # SacadoCnpjCpf - verificar consistência dos CPFs

# %%
[implementar]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 [implementar]
#
# NameError: name 'implementar' is not defined

# %% [markdown]
# df_final2.sample(3)

# %% [markdown]
# # Calcular % PDD em função de variáveis categóricas

# %%
cat_cols = ['Situacao', 'CedenteNome', 'SAC_TIPO_PESSOA', 'PagamentoParcial', 'TipoAtivo', '_MuitosContratos', '_MuitosEntes']

for col in cat_cols:
    aux_ = df_final2.groupby(col)[['_ValorLiquido', 'ValorPresente']].sum()
    aux_['%PDD'] = 1- aux_['_ValorLiquido'] / aux_['ValorPresente']
    display(aux_)
# Out:
#                _ValorLiquido  ValorPresente      %PDD
# Situacao
# Aditado         7.851224e+06   8.081707e+06  0.028519
# Sem cobranÃ§a   1.516009e+08   1.911504e+08  0.206903
#                                                 _ValorLiquido  ValorPresente  \
# CedenteNome
# BANCO DIGIMAIS S.A.                              2.469849e+05   2.972629e+05
# BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A   1.592051e+08   1.989349e+08
#
#                                                     %PDD
# CedenteNome
# BANCO DIGIMAIS S.A.                             0.169137
# BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A  0.199713
#                  _ValorLiquido  ValorPresente      %PDD
# SAC_TIPO_PESSOA
# F                 1.300191e+08   1.506257e+08  0.136807
# J                 2.943296e+07   4.860642e+07  0.394464
#                   _ValorLiquido  ValorPresente      %PDD
# PagamentoParcial
# NAO                1.593906e+08   1.989932e+08  0.199015
# SIM                6.149045e+04   2.389057e+05  0.742616
#                _ValorLiquido  ValorPresente      %PDD
# TipoAtivo
# CCB             1.509618e+08   1.902773e+08  0.206622
# CT - Contrato   8.490281e+06   8.954897e+06  0.051884
#                   _ValorLiquido  ValorPresente      %PDD
# _MuitosContratos
# False              1.591793e+08   1.989402e+08  0.199864
# True               2.728016e+05   2.919855e+05  0.065701
#               _ValorLiquido  ValorPresente      %PDD
# _MuitosEntes
# False          1.589462e+08   1.985388e+08  0.199420
# True           5.058947e+05   6.933760e+05  0.270389

# %% [markdown]
# # Repetir o item anterior para vencidos

# %%
for col in cat_cols:
    aux_ = df_final2.groupby(col)[['_ValorVencido', 'ValorPresente']].sum()
    aux_['%Vencido'] = (aux_['_ValorVencido'] / aux_['ValorPresente']) * 100
    display(aux_)
# Out:
#                _ValorVencido  ValorPresente  %Vencido
# Situacao
# Aditado             38818.61   8.081707e+06  0.480327
# Sem cobranÃ§a    10165952.80   1.911504e+08  5.318299
#                                                 _ValorVencido  ValorPresente  \
# CedenteNome
# BANCO DIGIMAIS S.A.                                  19910.86   2.972629e+05
# BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A    10184860.55   1.989349e+08
#
#                                                 %Vencido
# CedenteNome
# BANCO DIGIMAIS S.A.                             6.698064
# BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A  5.119696
#                  _ValorVencido  ValorPresente  %Vencido
# SAC_TIPO_PESSOA
# F                   6282185.49   1.506257e+08  4.170725
# J                   3922585.92   4.860642e+07  8.070099
#                   _ValorVencido  ValorPresente   %Vencido
# PagamentoParcial
# NAO                  9967888.88   1.989932e+08   5.009160
# SIM                   236882.53   2.389057e+05  99.153147
#                _ValorVencido  ValorPresente  %Vencido
# TipoAtivo
# CCB               9932005.12   1.902773e+08  5.219754
# CT - Contrato      272766.29   8.954897e+06  3.046001
#                   _ValorVencido  ValorPresente  %Vencido
# _MuitosContratos
# False               10197323.25   1.989402e+08  5.125824
# True                    7448.16   2.919855e+05  2.550866
#               _ValorVencido  ValorPresente  %Vencido
# _MuitosEntes
# False           10178132.62   1.985388e+08  5.126521
# True               26638.79   6.933760e+05  3.841897

# %% [markdown]
# # Sacados em mais de um ente?

# %%
# SacadoCnpjCpf , SacadoNome
sacados_entes = df_final2.groupby('SacadoCnpjCpf')['Convênio'].agg([pd.Series.nunique, pd.unique])
sacados_entes.sort_values('nunique', ascending=False)[:35]
#        'IdTituloVortx', 'TipoAtivo', 'DataEmissao', 'DataAquisicao',
#        'DataVencimento', 'NumeroBoleto', 'NumeroTitulo', 'CampoChave',
#        'ValorAquisicao', 'ValorNominal', 'ValorPresente', 'PDDNota',
#        'PDDVencido', 'PagamentoParcial', 'Coobricacao', 'DataGeracao',
#        'PDDTotal', 'CampoAdicional1', 'CampoAdicional2', 'CampoAdicional3',
#        'CampoAdicional4', 'CampoAdicional5', 'PDDEfeitoVagao',
#        'PercentagemEfeitoVagao', 'IdTituloVortxOriginador', 'Registradora',
#        'IdContratoRegistradora', 'IdTituloRegistradora', 'CCB', 'Convênio',
#        '_ValorLiquido'],
#       dtype='object')

# %%
df_final2.sample(2)
# Out:
#              Situacao PES_TIPO_PESSOA      CedenteCnpjCpf  \
# 608870  Sem cobranÃ§a               J  34.337.707/0001-00
# 343873  Sem cobranÃ§a               J  34.337.707/0001-00
#
#        TIT_CEDENTE_ENT_CODIGO                                     CedenteNome  \
# 608870                 318853  BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A
# 343873                 318853  BMP MONEY PLUS SOCIEDADE DE CREDITO DIRETO S.A
#
#            Cnae                                 SecaoCNAEDescricao NotaPdd  \
# 608870  6499999  OUTRAS ATIVIDADES DE SERVIÃOS FINANCEIROS NÃ...      AA
# 343873  6499999  OUTRAS ATIVIDADES DE SERVIÃOS FINANCEIROS NÃ...      AA
#
#        SAC_TIPO_PESSOA   SacadoCnpjCpf                     SacadoNome  \
# 608870               J  565.131.602-78  ISABEL GIANE COELHO RODRIGUES
# 343873               J  490.381.254-53    JOACILDO DE MEDEIROS GALVAO
#
#        IdTituloVortx TipoAtivo DataEmissao DataAquisicao DataVencimento  \
# 608870     100015359       CCB  2025-06-13    2025-06-16     2030-07-15
# 343873      41173845       CCB  2024-05-29    2024-05-31     2028-11-16
#
#        NumeroBoleto NumeroTitulo   CampoChave  ValorAquisicao  ValorNominal  \
# 608870          NaN  57139775060  57139775060          125.10        931.37
# 343873          NaN   3620565153    155164184            8.88         30.39
#
#         ValorPresente  PDDNota  PDDVencido PagamentoParcial Coobricacao  \
# 608870       128.9142      0.0         0.0              NAO         NAO
# 343873        12.0912      0.0         0.0              NAO         NAO
#
#        DataGeracao  PDDTotal CampoAdicional1 CampoAdicional2 CampoAdicional3  \
# 608870  2025-07-14       0.0             NaN             NaN             NaN
# 343873  2025-07-14       0.0             NaN             NaN             NaN
#
#        CampoAdicional4 CampoAdicional5  PDDEfeitoVagao  \
# 608870             NaN             NaN             0.0
# 343873             NaN             NaN             0.0
#
#         PercentagemEfeitoVagao IdTituloVortxOriginador Registradora  \
# 608870                     0.0                       0          NaN
# 343873                     0.0                       0          NaN
#
#        IdContratoRegistradora IdTituloRegistradora       CCB  \
# 608870                    NaN                  NaN  57139775
# 343873                    NaN                  NaN  36205651
#
#                         Convênio  _ValorLiquido  _ValorVencido  \
# 608870              PREF. JURUTI       128.9142            0.0
# 343873  GOV. RIO GRANDE DO NORTE        12.0912            0.0
#
#         _MuitosContratos
# 608870             False
# 343873             False
